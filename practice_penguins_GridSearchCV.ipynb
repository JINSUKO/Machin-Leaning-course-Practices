# %%
import pandas as pd

df = pd.read_csv('./penguins.csv')
df = df.drop(columns=['year'])
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 0         3750.0    male
# ...

# %%
df_bool1 = df['bill_length_mm'].isna()

for i, v in enumerate(df_bool1):
    if v == False:
        df_bool1[i] = True
    else:
        df_bool1[i] = False
        
df = df[df_bool1]

df.reset_index().drop(axis=1, columns=['index'])
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            36.7           19.3              193.0
# 4       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 337  Chinstrap      Dream            55.8           19.8              207.0
# 338  Chinstrap      Dream            43.5           18.1              202.0
# 339  Chinstrap      Dream            49.6           18.2              193.0
# 340  Chinstrap      Dream            50.8           19.0              210.0
# 341  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 0         3750.0    male
# ...

# %%
df_no_sex_data = df[df['sex'].isna()]

df_no_sex_data = df_no_sex_data.reset_index().drop(axis=1, columns=['index'])
df_no_sex_data
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            34.1           18.1              193.0
# 1  Adelie  Torgersen            42.0           20.2              190.0
# 2  Adelie  Torgersen            37.8           17.1              186.0
# 3  Adelie  Torgersen            37.8           17.3              180.0
# 4  Adelie      Dream            37.5           18.9              179.0
# 5  Gentoo     Biscoe            44.5           14.3              216.0
# 6  Gentoo     Biscoe            46.2           14.4              214.0
# 7  Gentoo     Biscoe            47.3           13.8              216.0
# 8  Gentoo     Biscoe            44.5           15.7              217.0
#
#    body_mass_g  sex
# 0       3475.0  NaN
# 1       4250.0  NaN
# 2       3300.0  NaN
# 3       3700.0  NaN
# 4       2975.0  NaN
# 5       4100.0  NaN
# 6       4650.0  NaN
# 7       4725.0  NaN
# 8       4875.0  NaN

# %%
df = df.dropna(how='any')
df = df.reset_index().drop(axis=1, columns=['index'])
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            36.7           19.3              193.0
# 4       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8              207.0
# 329  Chinstrap      Dream            43.5           18.1              202.0
# 330  Chinstrap      Dream            49.6           18.2              193.0
# 331  Chinstrap      Dream            50.8           19.0              210.0
# 332  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 0         3750.0    male
# ...

# %% [markdown]
# rom sklearn.preprocessing import OneHotEncoder 시도하였는데,
# 변경된 데이터에서 입력한 데이터프레임과 순서가 맞지 않아서 쓰지 get_dummies 이용함.
#
# --> DataFrame 변경 시 순서 문제가 발생한 것이었고, index=df_drop_island.index 파라미터를 사용하면 순서가 유지된다.

# %%
df_drop_island = df.drop(columns=['island'])
df_drop_island

species_list = df_drop_island['species'].unique()

from sklearn.preprocessing import OrdinalEncoder

ordinalencoder = OrdinalEncoder(categories=[species_list])

print(species_list)

df_species = pd.DataFrame(ordinalencoder.fit_transform(df_drop_island[['species']]), index=df_drop_island.index)

df_drop_island['species'] = df_species.rename(columns={0:"species"})
df_drop_island
# Out:
# ['Adelie' 'Gentoo' 'Chinstrap']
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0        0.0            39.1           18.7              181.0       3750.0
# 1        0.0            39.5           17.4              186.0       3800.0
# 2        0.0            40.3           18.0              195.0       3250.0
# 3        0.0            36.7           19.3              193.0       3450.0
# 4        0.0            39.3           20.6              190.0       3650.0
# ..       ...             ...            ...                ...          ...
# 328      2.0            55.8           19.8              207.0       4000.0
# 329      2.0            43.5           18.1              202.0       3400.0
# 330      2.0            49.6           18.2              193.0       3775.0
# 331      2.0            50.8           19.0              210.0       4100.0
# 332      2.0            50.2           18.7              198.0       3775.0
#
#         sex
# ...

# %%
df_drop_species = df.drop(columns=['species'])

island_list = df_drop_species['island'].unique()
print(island_list)

ordinalencoder = OrdinalEncoder(categories=[island_list])

df_island = pd.DataFrame(ordinalencoder.fit_transform(df_drop_species[['island']]), index=df_drop_species.index)

df_drop_species['island'] = df_island.rename(columns={0:"island"})
df_drop_species
# Out:
# ['Torgersen' 'Biscoe' 'Dream']
#      island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0       0.0            39.1           18.7              181.0       3750.0
# 1       0.0            39.5           17.4              186.0       3800.0
# 2       0.0            40.3           18.0              195.0       3250.0
# 3       0.0            36.7           19.3              193.0       3450.0
# 4       0.0            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 328     2.0            55.8           19.8              207.0       4000.0
# 329     2.0            43.5           18.1              202.0       3400.0
# 330     2.0            49.6           18.2              193.0       3775.0
# 331     2.0            50.8           19.0              210.0       4100.0
# 332     2.0            50.2           18.7              198.0       3775.0
#
#         sex
# 0      male
# ...

# %% [markdown]
# 성별 컬럼 one-hot encoding

# %%
y_species = df_drop_island['species']
df_species_data = df_drop_island.drop(axis=1, columns=['species'])
df_species_data = pd.get_dummies(df_species_data, dtype='int64')
df_species_data


y_island = df_drop_species['island']
df_island_data = df_drop_species.drop(axis=1, columns=['island'])
df_island_data = pd.get_dummies(df_island_data, dtype='int64')
df_island_data
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3              36.7           19.3              193.0       3450.0
# 4              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 328            55.8           19.8              207.0       4000.0
# 329            43.5           18.1              202.0       3400.0
# 330            49.6           18.2              193.0       3775.0
# 331            50.8           19.0              210.0       4100.0
# 332            50.2           18.7              198.0       3775.0
#
#      sex_female  sex_male
# 0             0         1
# 1             1         0
# 2             1         0
# 3             1         0
# ...

# %%
y_sex = df_island_data['sex_female']
y_sex.rename({'sex_female':'sex'})

df_sex_data = df_island_data.drop(axis=1, columns=['sex_female', 'sex_male'])

# %%
from sklearn.model_selection import train_test_split

X_species_train, X_species_test, y_species_train, y_species_test = train_test_split(df_species_data, y_species, random_state=42)
X_island_train, X_island_test, y_island_train, y_island_test = train_test_split(df_island_data, y_island, random_state=42)
X_sex_train, X_sex_test, y_sex_train, y_sex_test = train_test_split(df_sex_data, y_sex, random_state=42)

# %% [markdown]
# GridSearchCV 적용

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

params = {'min_impurity_decrease': [0.0001, 0.0002, 0.0003, 0.0004, 0.0005]}

gridsearch_species = GridSearchCV(DecisionTreeClassifier(random_state=42), params, n_jobs=-1)
gridsearch_species.fit(X_species_train, y_species_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'min_impurity_decrease': [0.0001, 0.0002, 0.0003,
#                                                    0.0004, 0.0005]})

# %%
dtClassifier = gridsearch_species.best_estimator_
dtClassifier
# Out:
# DecisionTreeClassifier(min_impurity_decrease=0.0001, random_state=42)

# %%
dtClassifier.score(X_species_train, y_species_train)
# Out:
# 1.0

# %%
gridsearch_species.best_params_
# Out:
# {'min_impurity_decrease': 0.0001}

# %%
gridsearch_species.cv_results_['mean_test_score']
# Out:
# array([0.9437551, 0.9437551, 0.9437551, 0.9437551, 0.9437551])

# %% [markdown]
# species data

# %%
import numpy as np

print(np.argmax(gridsearch_species.cv_results_['mean_test_score']))
print(max(gridsearch_species.cv_results_['mean_test_score']))
best_index = np.argmax(gridsearch_species.cv_results_['mean_test_score'])
# Out:
# 0
# 0.9437551020408164

# %%
gridsearch_species.cv_results_['params'][best_index]
# Out:
# {'min_impurity_decrease': 0.0001}

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(1, 20, 5),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(4, 10, 1),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':[5],
          'min_samples_split':np.arange(2, 100, 10)}

# %%
gridsearch_species = GridSearchCV(DecisionTreeClassifier(random_state=42), params, n_jobs=-1)
gridsearch_species.fit(X_species_train, y_species_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 gridsearch_species = GridSearchCV(DecisionTreeClassifier(random_state=42), params, n_jobs=-1).best_estimator_
#       2 gridsearch_species.fit(X_species_train, y_species_train)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
gridsearch_species.best_params_
# Out:
# {'max_depth': 6, 'min_impurity_decrease': 0.0001, 'min_samples_split': 2}

# %%
np.max(gridsearch_species.cv_results_['mean_test_score'])
# Out:
# 0.9437551020408164

# %%
print(gridsearch_species.best_estimator_.score(X_species_train, y_species_train))
print(gridsearch_species.best_estimator_.score(X_species_test, y_species_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 print(gridsearch_species.best_estimator_.score(X_species_train, y_species_train))
#       2 print(gridsearch_species.best_estimator_.score(X_species_test, y_species_test))
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'best_estimator_'

# %% [markdown]
# island data

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(1, 20, 5),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(3, 10, 1),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
gridsearch_island = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid=params, n_jobs=-1)
gridsearch_island.fit(X_island_train, y_island_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': array([3, 4, 5, 6, 7, 8, 9]),
#                          'min_impurity_decrease': array([0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008,
#        0.0009]),
#                          'min_samples_split': array([ 2, 12, 22, 32, 42, 52, 62, 72, 82, 92])})

# %%
print(gridsearch_island.best_params_)
max(gridsearch_island.cv_results_['mean_test_score'])
# Out:
# {'max_depth': 4, 'min_impurity_decrease': 0.0001, 'min_samples_split': 2}
# 0.7266122448979591

# %%
print(gridsearch_island.best_estimator_.score(X_island_train, y_island_train))
print(gridsearch_island.best_estimator_.score(X_island_test, y_island_test))
# Out:
# 0.8112449799196787
# 0.6190476190476191

# %% [markdown]
# sex data

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(1, 20, 5),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
params = {'min_impurity_decrease':np.arange(0.0001, 0.001, 0.0001),
          'max_depth':np.arange(7, 16, 1),
          'min_samples_split':np.arange(2, 100, 10)}

# %%
gridsearch_sex = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid=params, n_jobs=-1)
gridsearch_sex.fit(X_sex_train, y_sex_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': array([ 7,  8,  9, 10, 11, 12, 13, 14, 15]),
#                          'min_impurity_decrease': array([0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008,
#        0.0009]),
#                          'min_samples_split': array([ 2, 12, 22, 32, 42, 52, 62, 72, 82, 92])})

# %%
print(gridsearch_sex.best_params_)
max(gridsearch_sex.cv_results_['mean_test_score'])
# Out:
# {'max_depth': 8, 'min_impurity_decrease': 0.0008, 'min_samples_split': 2}
# 0.8874285714285713

# %%
print(gridsearch_sex.best_estimator_.score(X_sex_train, y_sex_train))
print(gridsearch_sex.best_estimator_.score(X_sex_test, y_sex_test))
# Out:
# 0.9919678714859438
# 0.8571428571428571
